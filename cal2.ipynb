# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Calibration 2 Plots

# %% [markdown]
# ## Plot 1

# %%
#importing and converting .dat files

#df = pd.read_csv('u11_49T170U32_84.dat', delimiter='\t')

#data = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/plot1/u11_49T170U32_84.dat',dtype=None,delimiter=',')

data1 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot1/u11T170u31.txt')
data2 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot1/u11T170u32.txt')
data3 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot1/u11T170u33.txt')

#print(data.shape)
#print(data)

#print(data[:,0])

u2_1 = data1[:,1]*10
uA_1 = data1[:,2]

u2_2 = data2[:,1]*10
uA_2 = data2[:,2]

u2_3 = data3[:,1]*10
uA_3 = data3[:,2]

# %%
plt.title('$U1 = 1.00V$ and $T = 170 ^{\circ} C$')
plt.plot(u2_1,uA_1,label='$U_{3} = 1.00V$')
plt.plot(u2_2,uA_2,label='$U_{2} = 2.00V$')
plt.plot(u2_3,uA_3,label='$U_{3} = 3.00V$')
plt.xlabel('voltage $U_{2}$ [V]')
plt.ylabel('voltage $U_{A}$ [V]')
plt.ylim(-0.5,5)
plt.legend()
plt.grid()
plt.savefig('cal2_plot1.png')

# %% [markdown]
# ### plot 2

# %%
#importing and converting .dat files

#df = pd.read_csv('u11_49T170U32_84.dat', delimiter='\t')

#data = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/plot1/u11_49T170U32_84.dat',dtype=None,delimiter=',')

data1 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot2/u11_5T170u32.txt')
data2 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot2/u11_5T170u33.txt')
data3 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot2/u11_5T170u34.txt')

#print(data.shape)
#print(data)

#print(data[:,0])

u2_1 = data1[:,1]*10
uA_1 = data1[:,2]

u2_2 = data2[:,1]*10
uA_2 = data2[:,2]

u2_3 = data3[:,1]*10
uA_3 = data3[:,2]

# %%
plt.title('$U1 = 1.50V$ and $T = 170 ^{\circ} C$')
plt.plot(u2_1,uA_1,label='$U_{3} = 2.00V$')
plt.plot(u2_2,uA_2,label='$U_{2} = 3.00V$')
plt.plot(u2_3,uA_3,label='$U_{3} = 4.00V$')
plt.xlabel('voltage $U_{2}$ [V]')
plt.ylabel('voltage $U_{A}$ [V]')
plt.ylim(-0.5,5)
plt.legend()
plt.grid()
plt.savefig('cal2_plot2.png')

# %% [markdown]
# ## PLot 3

# %%
#importing and converting .dat files

#df = pd.read_csv('u11_49T170U32_84.dat', delimiter='\t')

#data = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/plot1/u11_49T170U32_84.dat',dtype=None,delimiter=',')

data1 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot3/u12T170u33.txt')
data2 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot3/u12T170u33_75.txt')
data3 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot3/u12T170u34_6.txt')

#print(data.shape)
#print(data)

#print(data[:,0])

u2_1 = data1[:,1]*10
uA_1 = data1[:,2]

u2_2 = data2[:,1]*10
uA_2 = data2[:,2]

u2_3 = data3[:,1]*10
uA_3 = data3[:,2]

# %%
plt.title('$U1 = 2.00V$ and $T = 170 ^{\circ} C$')
plt.plot(u2_1,uA_1,label='$U_{3} = 3.00V$')
plt.plot(u2_2,uA_2,label='$U_{2} = 3.75V$')
plt.plot(u2_3,uA_3,label='$U_{3} = 4.60V$')
plt.xlabel('voltage $U_{2}$ [V]')
plt.ylabel('voltage $U_{A}$ [V]')
plt.ylim(-0.5,5)
plt.legend()
plt.grid()
plt.savefig('cal2_plot3.png')

# %% [markdown]
# ## plot 4

# %%
#importing and converting .dat files

#df = pd.read_csv('u11_49T170U32_84.dat', delimiter='\t')

#data = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/plot1/u11_49T170U32_84.dat',dtype=None,delimiter=',')

data1 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot4/u12_25T170u33_5.txt')
data2 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot4/u12_25T170u33_75.txt')
data3 = np.genfromtxt('/Users/larsbaltensperger/Desktop/Physikpraktikum3/Franck_Hertz/cal2/plot4/u12_25T170u34.txt')

#print(data.shape)
#print(data)

#print(data[:,0])

u2_1 = data1[:,1]*10
uA_1 = data1[:,2]

u2_2 = data2[:,1]*10
uA_2 = data2[:,2]

u2_3 = data3[:,1]*10
uA_3 = data3[:,2]

# %%
plt.title('$U1 = 2.25V$ and $T = 170 ^{\circ} C$')
plt.plot(u2_1,uA_1,label='$U_{3} = 3.50V$')
plt.plot(u2_2,uA_2,label='$U_{2} = 3.75V$')
plt.plot(u2_3,uA_3,label='$U_{3} = 4.00V$')
plt.xlabel('voltage $U_{2}$ [V]')
plt.ylabel('voltage $U_{A}$ [V]')
plt.ylim(-0.5,6)
plt.legend()
plt.grid()
plt.savefig('cal2_plot4.png')
